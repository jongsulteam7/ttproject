# %% [markdown]
# # 노출/비노출 분류

# %%
pip install tensorflow

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import * 
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %%
# sample for testset
data = {"id": list(range(1, 183)), "label": [0]*182}
df = pd.DataFrame(data)

# 비어있는 라벨 데이터[0] csv 파일로 저장
df.to_csv("/content/drive/MyDrive/ttproject/Sequential/선정성/노출/sample.csv", index=False)

# %%
# 경로 설정 - 노출/비노출 trainset, 각각 500개씩 합쳐져있는 폴더
path = "/content/drive/MyDrive/ttproject/Sequential/선정성/노출/dataset/노출train_new"
files = os.listdir(path)

for file in files:
    if file == ".DS_Store":
        os.remove(os.path.join(dpath, file))

# %%
# 데이터 형상 관련 상수 정의 
IMAGE_WIDTH = 216
IMAGE_HEIGHT = 216
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNEL = 3

# 학습 데이터 준비 
filenames = os.listdir(path)

df = pd.DataFrame(
    {"filename":sorted(filenames),
    "category":0}
)      
df
# Out:
#                  filename  category
# 0      노출이미지001.jpg         0
# 1      노출이미지002.jpg         0
# 2      노출이미지003.jpg         0
# 3      노출이미지004.jpg         0
# 4      노출이미지005.jpg         0
# ..                    ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [1000 rows x 2 columns]

# %%
# 노출=1, 비노출= 0으로 정답 레이블 (category) 생성
df.loc[:499, "category"] = 1

exposure_rows = df[df["category"] == 1]
print(exposure_rows)
# Out:
#                filename  category
# 0    노출이미지001.jpg         1
# 1    노출이미지002.jpg         1
# 2    노출이미지003.jpg         1
# 3    노출이미지004.jpg         1
# 4    노출이미지005.jpg         1
# ..                  ...       ...
# 495  노출이미지496.jpg         1
# 496  노출이미지497.jpg         1
# 497  노출이미지498.JPG         1
# 498  노출이미지499.jpg         1
# 499  노출이미지500.jpg         1
#
# [500 rows x 2 columns]

# %%
# 확인 
nonexposure_rows = df[df["category"] == 0]
print(nonexposure_rows)

df
# Out:
#                  filename  category
# 500  비노출이미지001.jpg         0
# 501  비노출이미지002.jpg         0
# 502  비노출이미지003.jpg         0
# 503  비노출이미지004.jpg         0
# 504  비노출이미지005.jpg         0
# ..                    ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [500 rows x 2 columns]
#                  filename  category
# 0      노출이미지001.jpg         1
# 1      노출이미지002.jpg         1
# 2      노출이미지003.jpg         1
# 3      노출이미지004.jpg         1
# 4      노출이미지005.jpg         1
# ..                    ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [1000 rows x 2 columns]

# %%
df['category'].value_counts().plot.bar()
plt.show()

# %%
# %matplotlib inline
from tensorflow.keras.preprocessing.image import load_img

# 샘플 이미지 불러오기
sample = random.choice(filenames)
img_path = os.path.join(path, sample)
image = load_img(img_path)
plt.imshow(image)

# %%
# 배치정규화(Batch Normalization): 신경망 입력 데이터를 평균 : 0 , 분산: 1로 정규화를 해서 학습이 잘 이루어지도록 하는 방법 

# 모델 생성

from keras.models import Sequential
from keras.layers import *

# %%
# 레이어 1
model = Sequential()
model.add(Conv2D(32, (3,3), activation="relu", input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH , IMAGE_CHANNEL)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 레이어 2 
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 레이어3
model.add(Conv2D(128, (3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
          
# Fully Connected 
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2,activation="softmax"))

# %%
# 모델 실행 옵션 
model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 214, 214, 32)      896
#
#  batch_normalization_4 (Batc  (None, 214, 214, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 107, 107, 32)     0
#  2D)
#
#  dropout_4 (Dropout)         (None, 107, 107, 32)      0
#
#  conv2d_4 (Conv2D)           (None, 105, 105, 64)      18496
#
#  batch_normalization_5 (Batc  (None, 105, 105, 64)     256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 52, 52, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 52, 52, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 50, 50, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 50, 50, 128)      512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 25, 25, 128)       0
#
#  flatten_1 (Flatten)         (None, 80000)             0
#
#  dense_2 (Dense)             (None, 512)               40960512
#
#  batch_normalization_7 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 41,057,730
# Trainable params: 41,056,258
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# reduceLROnPlateau: 모델의 정확도가 향상되지 않는 경우 ㅡ learning rate (lr) 을 줄여주는 클래스
# : callback 함수의 일종, learning rate가 더이상 업데이트가 되지 않으면, 학습을 중단해라
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(patience=10)
learning_rate_reduction=ReduceLROnPlateau(
                        monitor= "val_accuracy", 
                        patience = 2, 
                        factor = 0.5, 
                        min_lr=0.0001,
                        verbose=1)
                        
callbacks = [earlystop, learning_rate_reduction]

# %%
# 이미지 제너레이터에서 class_mode = "categorical"로 지정하기 위해 컬럼 카테고리를 스트링으로 변경함. 
df['category']=df['category'].replace({0:'비노출',1:"노출"})

# %%
# test, validate 데이터 분리
# 비율 7:3으로 조정
train_df, validate_df = train_test_split(df , test_size=0.3, random_state= 42)

train_df=train_df.reset_index(drop=True)
validate_df=validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts()
# Out:
# 비노출    350
# 노출     350
# Name: category, dtype: int64

# %%
validate_df['category'].value_counts()
# Out:
# 비노출    150
# 노출     150
# Name: category, dtype: int64

# %%
total_train=train_df.shape[0]
total_validate=validate_df.shape[0]
batch_size=8

# 트레이닝 데이터의 제너레이터 설정 
train_datagen=ImageDataGenerator(
        rotation_range=15,
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.2,
        horizontal_flip=True,
        width_shift_range=0.1, 
        height_shift_range=0.1)
        
train_generator=train_datagen.flow_from_dataframe(
    train_df, 
    path,
    x_col = "filename", 
    y_col = "category",
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size )
    
validate_datagen=ImageDataGenerator(rescale=1./255)
# 검증이미지니까, 사진 그대로 쓰겠다. 

validation_generator=validate_datagen.flow_from_dataframe(
    validate_df,
    path,
    x_col= "filename",
    y_col= "category",
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size )
# Out:
# Found 700 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.

# %%
# 샘플 데이터 확인
example_df=train_df.sample(n=1).reset_index(drop=True)
example_df
# Out:
#              filename category
# 0  노출이미지126.jpg       노출

# %%
example_generator = train_datagen.flow_from_dataframe(
                    example_df,
                    path,
                    x_col = "filename",
                    y_col = "category",
                    target_size = IMAGE_SIZE,
                    class_mode = "categorical")
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(10,10))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for xBatch, yBatch in example_generator:
        image = xBatch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
from PIL import Image, ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ## 모델 학습

# %%
# 가장 높은 성능의 모델을 저장
# 콜백값에 추가해서 EarlyStopping, ReduceLROnPlateau랑 같이 사용
# 그러면 학습 중에 성능 향상이 없는 경우 조기 종료하고, 학습률을 조정하면서, 가장 좋은 성능의 모델 가중치를 저장할 수 있다!
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

callbacks = [earlystop, learning_rate_reduction, checkpoint]

# %%
# 트레이닝
epochs = 50

history = model.fit(
    train_generator, 
    epochs = epochs, 
    steps_per_epoch = total_train//batch_size ,
    validation_data=  validation_generator,
    validation_steps = total_validate//batch_size,
    callbacks = callbacks,
)

# 모델 저장 
model.save("/content/drive/MyDrive/ttproject/Sequential/선정성/노출/naked_model.h5")


## truncated = True로 설정
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 1.2384 - accuracy: 0.6156
# Epoch 1: val_accuracy improved from -inf to 0.50338, saving model to weights.h5
# 87/87 [==============================] - 520s 6s/step - loss: 1.2384 - accuracy: 0.6156 - val_loss: 3.5279 - val_accuracy: 0.5034 - lr: 0.0010
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.9929 - accuracy: 0.6329
# Epoch 2: val_accuracy did not improve from 0.50338
# 87/87 [==============================] - 23s 267ms/step - loss: 0.9929 - accuracy: 0.6329 - val_loss: 1.9100 - val_accuracy: 0.5034 - lr: 0.0010
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.7276 - accuracy: 0.7168
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 3: val_accuracy did not improve from 0.50338
# 87/87 [==============================] - 24s 278ms/step - loss: 0.7276 - accuracy: 0.7168 - val_loss: 2.4531 - val_accuracy: 0.5034 - lr: 0.0010
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.7673
# Epoch 4: val_accuracy improved from 0.50338 to 0.57770, saving model to weights.h5
# 87/87 [==============================] - 31s 357ms/step - loss: 0.5983 - accuracy: 0.7673 - val_loss: 1.0563 - val_accuracy: 0.5777 - lr: 5.0000e-04
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.7861
# Epoch 5: val_accuracy did not improve from 0.57770
# 87/87 [==============================] - 24s 282ms/step - loss: 0.4899 - accuracy: 0.7861 - val_loss: 0.9989 - val_accuracy: 0.5709 - lr: 5.0000e-04
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.7659
# Epoch 6: val_accuracy improved from 0.57770 to 0.67905, saving model to weights.h5
# 87/87 [==============================] - 30s 343ms/step - loss: 0.5204 - accuracy: 0.7659 - val_loss: 0.6433 - val_accuracy: 0.6791 - lr: 5.0000e-04
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.5188 - accuracy: 0.7746
# Epoch 7: val_accuracy improved from 0.67905 to 0.70946, saving model to weights.h5
# 87/87 [==============================] - 26s 301ms/step - loss: 0.5188 - accuracy: 0.7746 - val_loss: 0.8142 - val_accuracy: 0.7095 - lr: 5.0000e-04
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.7861
# Epoch 8: val_accuracy improved from 0.70946 to 0.73986, saving model to weights.h5
# 87/87 [==============================] - 25s 291ms/step - loss: 0.5127 - accuracy: 0.7861 - val_loss: 0.7279 - val_accuracy: 0.7399 - lr: 5.0000e-04
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.5246 - accuracy: 0.7543
# Epoch 9: val_accuracy did not improve from 0.73986
# 87/87 [==============================] - 29s 333ms/step - loss: 0.5246 - accuracy: 0.7543 - val_loss: 0.5618 - val_accuracy: 0.7365 - lr: 5.0000e-04
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.7905
# Epoch 10: val_accuracy improved from 0.73986 to 0.79054, saving model to weights.h5
# 87/87 [==============================] - 30s 345ms/step - loss: 0.4893 - accuracy: 0.7905 - val_loss: 0.5398 - val_accuracy: 0.7905 - lr: 5.0000e-04
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.8078
# Epoch 11: val_accuracy did not improve from 0.79054
# 87/87 [==============================] - 25s 293ms/step - loss: 0.4380 - accuracy: 0.8078 - val_loss: 0.6335 - val_accuracy: 0.7838 - lr: 5.0000e-04
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.7948
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_accuracy did not improve from 0.79054
# 87/87 [==============================] - 29s 338ms/step - loss: 0.4511 - accuracy: 0.7948 - val_loss: 0.6721 - val_accuracy: 0.7601 - lr: 5.0000e-04
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.8006
# Epoch 13: val_accuracy did not improve from 0.79054
# 87/87 [==============================] - 27s 309ms/step - loss: 0.4564 - accuracy: 0.8006 - val_loss: 0.5037 - val_accuracy: 0.7770 - lr: 2.5000e-04
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.8165
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 14: val_accuracy did not improve from 0.79054
# 87/87 [==============================] - 25s 293ms/step - loss: 0.4522 - accuracy: 0.8165 - val_loss: 0.4849 - val_accuracy: 0.7872 - lr: 2.5000e-04
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4302 - accuracy: 0.8064
# Epoch 15: val_accuracy improved from 0.79054 to 0.80068, saving model to weights.h5
# 87/87 [==============================] - 26s 302ms/step - loss: 0.4302 - accuracy: 0.8064 - val_loss: 0.4704 - val_accuracy: 0.8007 - lr: 1.2500e-04
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8208
# Epoch 16: val_accuracy improved from 0.80068 to 0.80405, saving model to weights.h5
# 87/87 [==============================] - 26s 302ms/step - loss: 0.4298 - accuracy: 0.8208 - val_loss: 0.4659 - val_accuracy: 0.8041 - lr: 1.2500e-04
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8598
# Epoch 17: val_accuracy did not improve from 0.80405
# 87/87 [==============================] - 25s 291ms/step - loss: 0.3511 - accuracy: 0.8598 - val_loss: 0.4938 - val_accuracy: 0.8041 - lr: 1.2500e-04
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8194
# Epoch 18: val_accuracy improved from 0.80405 to 0.80743, saving model to weights.h5
# 87/87 [==============================] - 31s 352ms/step - loss: 0.3754 - accuracy: 0.8194 - val_loss: 0.4679 - val_accuracy: 0.8074 - lr: 1.2500e-04
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8092
# Epoch 19: val_accuracy improved from 0.80743 to 0.81081, saving model to weights.h5
# 87/87 [==============================] - 26s 295ms/step - loss: 0.4238 - accuracy: 0.8092 - val_loss: 0.5022 - val_accuracy: 0.8108 - lr: 1.2500e-04
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8512
# Epoch 20: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 286ms/step - loss: 0.3676 - accuracy: 0.8512 - val_loss: 0.5467 - val_accuracy: 0.7736 - lr: 1.2500e-04
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8280
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 21: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 285ms/step - loss: 0.4003 - accuracy: 0.8280 - val_loss: 0.4923 - val_accuracy: 0.7939 - lr: 1.2500e-04
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8367
# Epoch 22: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 286ms/step - loss: 0.3754 - accuracy: 0.8367 - val_loss: 0.5056 - val_accuracy: 0.7939 - lr: 1.0000e-04
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4599 - accuracy: 0.7991
# Epoch 23: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 284ms/step - loss: 0.4599 - accuracy: 0.7991 - val_loss: 0.4639 - val_accuracy: 0.8074 - lr: 1.0000e-04
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8497
# Epoch 24: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 292ms/step - loss: 0.3350 - accuracy: 0.8497 - val_loss: 0.5007 - val_accuracy: 0.7872 - lr: 1.0000e-04
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8223
# Epoch 25: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 285ms/step - loss: 0.3972 - accuracy: 0.8223 - val_loss: 0.4571 - val_accuracy: 0.8074 - lr: 1.0000e-04
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.8367
# Epoch 26: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 24s 281ms/step - loss: 0.3672 - accuracy: 0.8367 - val_loss: 0.4460 - val_accuracy: 0.8108 - lr: 1.0000e-04
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3843 - accuracy: 0.8309
# Epoch 27: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 291ms/step - loss: 0.3843 - accuracy: 0.8309 - val_loss: 0.5694 - val_accuracy: 0.7804 - lr: 1.0000e-04
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3729 - accuracy: 0.8396
# Epoch 28: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 285ms/step - loss: 0.3729 - accuracy: 0.8396 - val_loss: 0.5347 - val_accuracy: 0.7939 - lr: 1.0000e-04
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.8410
# Epoch 29: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 293ms/step - loss: 0.3695 - accuracy: 0.8410 - val_loss: 0.4801 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.4291 - accuracy: 0.8295
# Epoch 30: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 26s 304ms/step - loss: 0.4291 - accuracy: 0.8295 - val_loss: 0.5067 - val_accuracy: 0.7770 - lr: 1.0000e-04
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.8251
# Epoch 31: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 24s 281ms/step - loss: 0.3798 - accuracy: 0.8251 - val_loss: 0.4832 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3709 - accuracy: 0.8540
# Epoch 32: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 24s 277ms/step - loss: 0.3709 - accuracy: 0.8540 - val_loss: 0.4819 - val_accuracy: 0.7973 - lr: 1.0000e-04
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8555
# Epoch 33: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 29s 335ms/step - loss: 0.3468 - accuracy: 0.8555 - val_loss: 0.4919 - val_accuracy: 0.7872 - lr: 1.0000e-04
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8540
# Epoch 34: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 29s 334ms/step - loss: 0.3488 - accuracy: 0.8540 - val_loss: 0.4851 - val_accuracy: 0.7872 - lr: 1.0000e-04
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8569
# Epoch 35: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 284ms/step - loss: 0.3481 - accuracy: 0.8569 - val_loss: 0.4699 - val_accuracy: 0.7872 - lr: 1.0000e-04
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.3919 - accuracy: 0.8266
# Epoch 36: val_accuracy did not improve from 0.81081
# 87/87 [==============================] - 25s 288ms/step - loss: 0.3919 - accuracy: 0.8266 - val_loss: 0.4957 - val_accuracy: 0.7838 - lr: 1.0000e-04

# %% [markdown]
# ## 트레이닝 모델 히스토리 시각화

# %%
# 트레이닝 모델 히스토리 시각화 

historyDict=history.history

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

# %matplotlib inline
epo = range(1, len(acc)+1)
plt.plot(epo, loss, 'bo', label="Traing loss")
plt.plot(epo, val_loss, 'b', label="Val loss")
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# %matplotlib inline
plt.plot(epo, acc, 'ro', label="Traing accuracy")
plt.plot(epo, val_acc, 'r', label="Val accuracy")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## 과적합 확인

# %%
# 과적합 확인용
from matplotlib import pyplot as plt

plt.plot(epo, acc, 'r', label='Training accuracy')
plt.plot(epo, val_acc, 'b', label='Val accuracy')
plt.title('Training and testing accuracy')
plt.legend()
plt.figure()

plt.plot(epo, loss, 'r', label='Training loss')
plt.plot(epo, val_loss, 'b', label='Val loss')
plt.title('Training and testing loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 최종 모델
#
# - Epoch 19
#
# - accuracy: 0.8092
# - val_accuracy: 0.8108
# - loss: 0.4238
# - val_loss: 0.5022
# - lr: 1.2500e-04
