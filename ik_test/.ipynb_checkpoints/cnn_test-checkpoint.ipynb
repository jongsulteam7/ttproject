# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import * 
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt 
import random
import os
# Out:
# 2023-05-11 19:14:52.163316: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = {"id": list(range(1, 1001)), "label": [0]*1000}
df = pd.DataFrame(data)

# csv 파일로 저장
df.to_csv("/Users/inkyung/Desktop/IT_Projects/ttproject/ik_test/sample.csv", index=False)

# %%
path = "/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train"
files = os.listdir(path)

for file in files:
    if file == ".DS_Store":
        os.remove(os.path.join(dpath, file))

# %%
# 데이터 형상 관련 상수 정의 
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNEL = 3

# 학습 데이터 준비 
filenames = os.listdir(path)

df = pd.DataFrame(
    {"filename":sorted(filenames),
    "category":0}
)      
df
# Out:
#           filename  category
# 0     노출이미지001.jpg         0
# 1     노출이미지002.jpg         0
# 2     노출이미지003.jpg         0
# 3     노출이미지004.jpg         0
# 4     노출이미지005.jpg         0
# ..             ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [1000 rows x 2 columns]

# %%
# 노출=1, 비노출= 0으로 정답 레이블 (category) 생성
df.loc[:499, "category"] = 1

exposure_rows = df[df["category"] == 1]
print(exposure_rows)
# Out:
#          filename  category
# 0    노출이미지001.jpg         1
# 1    노출이미지002.jpg         1
# 2    노출이미지003.jpg         1
# 3    노출이미지004.jpg         1
# 4    노출이미지005.jpg         1
# ..            ...       ...
# 495  노출이미지496.jpg         1
# 496  노출이미지497.jpg         1
# 497  노출이미지498.JPG         1
# 498  노출이미지499.jpg         1
# 499  노출이미지500.jpg         1
#
# [500 rows x 2 columns]

# %%
# 확인 
nonexposure_rows = df[df["category"] == 0]
print(nonexposure_rows)

df
# Out:
#           filename  category
# 500  비노출이미지001.jpg         0
# 501  비노출이미지002.jpg         0
# 502  비노출이미지003.jpg         0
# 503  비노출이미지004.jpg         0
# 504  비노출이미지005.jpg         0
# ..             ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [500 rows x 2 columns]
#           filename  category
# 0     노출이미지001.jpg         1
# 1     노출이미지002.jpg         1
# 2     노출이미지003.jpg         1
# 3     노출이미지004.jpg         1
# 4     노출이미지005.jpg         1
# ..             ...       ...
# 995  비노출이미지496.jpg         0
# 996  비노출이미지497.jpg         0
# 997  비노출이미지498.jpg         0
# 998  비노출이미지499.jpg         0
# 999  비노출이미지500.jpg         0
#
# [1000 rows x 2 columns]

# %%
# %matplotlib notebook
df['category'].value_counts().plot.bar()
# 데이터 비율 1:1
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# 폴더 경로 합치기 -> Mac OS에서는 이렇게... 이거 때문에 경로설정 잘못된거 엄청 오래 찾음...ㅎ
'''
parent_dir = "/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출:비노출"
folders = ["노출 이미지", "비노출 이미지"]

for folder in folders:
    folder_path = os.path.join(parent_dir, folder)
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
'''
# 근데 이렇게 하면 두 폴더 내에 이미지에 액세스는 가능한데 각각의 경로를 합치지는 못함. -> 그냥 train 폴더 합쳐버림

path
# Out:
# '/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train'

# %%
# %matplotlib notebook
from tensorflow.keras.preprocessing.image import load_img

# 샘플 이미지 불러오기
sample = random.choice(filenames)
img_path = os.path.join(path, sample)
image = load_img(img_path)
plt.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 배치정규화(Batch Normalization): 신경망 입력 데이터를 평균 : 0 , 분산: 1로 정규화를 해서 학습이 잘 이루어지도록 하는 방법 

# 모델 생성

from keras.models import Sequential
from keras.layers import *

# %%
# 레이어 1
model = Sequential()
model.add(Conv2D(32, (3,3), activation="relu", input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH , IMAGE_CHANNEL)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 레이어 2 
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# 레이어3
model.add(Conv2D(128, (3,3), activation="relu"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
          
# Fully Connected 
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2,activation="softmax"))

# %%
# 모델 실행 옵션 
model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      896
#
#  batch_normalization_4 (Batc  (None, 126, 126, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 63, 63, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 128)       0
#
# ...

# %%
# reduceLROnPlateau 
# : callback 함수의 일종, learning rate가 더이상 업데이트가 되지 않으면, 학습을 중단해라
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(patience=10)
learning_rate_reduction=ReduceLROnPlateau(
                        monitor= "val_accuracy", 
                        patience = 2, 
                        factor = 0.5, 
                        min_lr=0.0001,
                        verbose=1)
                        
callbacks = [earlystop, learning_rate_reduction]

# %%
# 이미지 제너레이터에서 class_mode = "categorical"로 지정하기 위해 컬럼 카테고리를 스트링으로 변경함. 
df['category']=df['category'].replace({0:'비노출',1:"노출"})

# %%
# test, train 데이터 분리

train_df, validate_df = train_test_split(df , test_size=0.2, random_state= 42)

train_df=train_df.reset_index(drop=True)
validate_df=validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts()
# Out:
# 노출     404
# 비노출    396
# Name: category, dtype: int64

# %%
validate_df['category'].value_counts()
# Out:
# 비노출    104
# 노출      96
# Name: category, dtype: int64

# %%
total_train=train_df.shape[0]
total_validate=validate_df.shape[0]
batch_size=10

# 트레이닝 데이터의 제너레이터 설정 
train_datagen=ImageDataGenerator(
        rotation_range=15,
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.2,
        horizontal_flip=True,
        width_shift_range=0.1, 
        height_shift_range=0.1)
        
train_generator=train_datagen.flow_from_dataframe(
    train_df, 
    path,
    x_col = "filename", 
    y_col = "category",
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size )
    
validate_datagen=ImageDataGenerator(rescale=1./255)
# 검증이미지니까, 사진 그대로 쓰겠다. 

validation_generator=validate_datagen.flow_from_dataframe(
    validate_df,
    path,
    x_col= "filename",
    y_col= "category",
    target_size = IMAGE_SIZE,
    class_mode = "categorical",
    batch_size = batch_size )
# Out:
# Found 800 validated image filenames belonging to 2 classes.
# Found 200 validated image filenames belonging to 2 classes.

# %%
# 샘플 데이터 확인
example_df=train_df.sample(n=1).reset_index(drop=True)
example_df
# Out:
#         filename category
# 0  비노출이미지009.jpg      비노출

# %%
example_generator = train_datagen.flow_from_dataframe(
                    example_df,
                    path,
                    x_col = "filename",
                    y_col = "category",
                    target_size = IMAGE_SIZE,
                    class_mode = "categorical")
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(10,10))
for i in range(0,15):
    plt.subplot(5,3,i+1)
    for xBatch, yBatch in example_generator:
        image = xBatch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from PIL import Image, ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
pip install keras --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 트레이닝

epochs = 5

history = model.fit_generator(
    train_generator, 
    epochs = epochs, 
    steps_per_epoch = total_train//batch_size ,
    validation_data=  validation_generator,
    validation_steps = total_validate//batch_size,
    callbacks = callbacks,
)

# 모델 저장 
model.save_weights("model.h5")


## truncated = True로 설정
# Out:
# /var/folders/2x/pptt888d2_x9jxvslsglvm0w0000gn/T/ipykernel_86036/2021077940.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/5
# 2023-05-11 20:01:38.685647: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 80/80 [==============================] - ETA: 0s - loss: 0.7584 - accuracy: 0.6250
# 2023-05-11 20:02:47.933440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# ...

# %%
# 트레이닝 모델 히스토리 시각화 

historyDict=history.history

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

# %matplotlib notebook
epo = range(1, len(acc)+1)
plt.plot(epo, loss, 'bo', label="Traing loss")
plt.plot(epo, val_loss, 'b', label="Val loss")
plt.xlabel("epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(epo, acc, 'ro', label="Traing accuracy")
plt.plot(epo, val_acc, 'r', label="Val accuracy")
plt.xlabel("epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 테스트 데이터가 따로 없어서 이미지 소스 다시 사용
filenames = os.listdir("/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train")

test_df=pd.DataFrame( {"filename":filenames} )      
test_df
# Out:
#           filename
# 0    비노출이미지340.jpg
# 1    비노출이미지426.jpg
# 2    비노출이미지432.jpg
# 3    비노출이미지354.jpg
# 4    비노출이미지368.jpg
# ..             ...
# 995  비노출이미지371.jpg
# 996  비노출이미지417.jpg
# 997  비노출이미지403.jpg
# 998  비노출이미지365.jpg
# 999  비노출이미지359.jpg
#
# [1000 rows x 1 columns]

# %%
nbsamples=test_df.shape[0]
nbsamples
# Out:
# 1000

# %%
# 테스트 데이터 생성
test_df = pd.DataFrame({"filename": filenames})
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    test_df,
    "/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train",
    x_col="filename",
    y_col=None,
    target_size=IMAGE_SIZE,
    class_mode=None,
    batch_size=15,
    shuffle=True
)
# Out:
# Found 1000 validated image filenames.

# %%
# 예측 
predict=model.predict_generator(test_generator, 
                                steps=nbsamples/batch_size, 
                                callbacks=callbacks)
                                
test_df['category']=np.argmax(predict, axis=1)
# Out:
# /var/folders/2x/pptt888d2_x9jxvslsglvm0w0000gn/T/ipykernel_86036/3537130117.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict=model.predict_generator(test_generator,
# 2023-05-11 20:08:14.669266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 100.0 batches). You may need to use the repeat() function when building your dataset.

# %%
# 테스트 샘플 랜덤으로 추출해서 확인 

test_df['category']=test_df['category'].replace({0:'비노출',1:"노출"})
ex_df=test_df.sample(n=1).reset_index(drop=True)
ex_df
# Out:
#         filename category
# 0  비노출이미지112.jpg      비노출

# %%
ex_generator = test_datagen.flow_from_dataframe(
                    ex_df,
                    "/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train",
                    x_col = "filename",
                    y_col = None,
                    target_size = IMAGE_SIZE,
                    class_mode = None)
# Out:
# Found 1 validated image filenames.

# %%
test_sample=list(ex_df.filename)

sample = ""
for test in test_sample:
    sample += test

# %%
path = os.path.join("/Users/inkyung/Desktop/IT_Projects/ttproject/선정적 이미지 소스/노출train", sample)
image = load_img(path)
plt.figure(figsize=(8,8))
plt.imshow(image)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sampleSubmission=pd.read_csv("/Users/inkyung/Desktop/IT_Projects/ttproject/ik_test/sample.csv", dtype="object")
sampleSubmission

index=[]
for filename in test_df.filename:
    #li=filename.split(".")[0]
    index.append(li)
    
test_df["id"]=index

final=test_df.merge(sampleSubmission)[['id','category']]
final['id']=final['id'].astype("int64")
final=final.sort_values("id")

final.rename({'category':"label"},axis='columns').to_csv("Submission.csv", index=False)
